# %%
import pandas as pd

# %%
# keys = 'dataset task_type size n_features key'.split(' ')
# df = pd.read_csv('metrics.csv', index_col= keys)
df = pd.read_csv('metrics.csv')

# %%
df
# Out:
#    dataset task_type   size  n_features                          key  \
# 0       AD  binclass  48842          14                  (E) MLP-PLR
# 1       AD  binclass  48842          14                     (E) TabR
# 2       AD  binclass  48842          14        (E) MLP-PLR (adagrad)
# 3       AD  binclass  48842          14                      MLP-PLR
# 4       AD  binclass  48842          14                         TabR
# 5       AD  binclass  48842          14            MLP-PLR (adagrad)
# 6       AD  binclass  48842          14      (E) MLP-PLR (mechanize)
# 7       AD  binclass  48842          14           (E) MLP-PLR (lion)
# 8       AD  binclass  48842          14        (E) MLP-PLR (prodigy)
# 9       AD  binclass  48842          14            (E) MLP-PLR (sgd)
# 10      AD  binclass  48842          14               MLP-PLR (lion)
# 11      AD  binclass  48842          14            MLP-PLR (prodigy)
# 12      AD  binclass  48842          14                MLP-PLR (sgd)
# ...

# %%
df[['key', 'test_mean', 'test_std']].to_excel(index=False, excel_writer='metrics.xlsx')
