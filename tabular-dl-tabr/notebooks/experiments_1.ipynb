# %%
import subprocess
import os 

file_names = [
    # "my_lr_adagrad-tuning.toml",
    # "my_lr_adamW-tuning.toml",
    # "my_lr_FW_Vanilla_R_2-tuning.toml",
    # "my_lr_lbfgs-tuning.toml", # Пока не доделали
    "my_lr_lion-tuning.toml",
    "my_lr_mechanize-tuning.toml",
    # "my_lr_mirrorGD_entropy-tuning.toml", # Пока не работает
    "my_lr_prodigy-tuning.toml",
    "my_lr_projGD_R_2-tuning.toml",
    "my_lr_rmsprop-tuning.toml",
    "my_lr_sgd-tuning.toml",
    "my_lr_signsgd-tuning.toml",

    "my_plr_adagrad-tuning.toml",
    "my_plr_adamW-tuning.toml",
    "my_plr_FW_Vanilla_R_2-tuning.toml",
    # "my_plr_lbfgs-tuning.toml", # Пока не доделали
    "my_plr_lion-tuning.toml",
    "my_plr_mechanize-tuning.toml",
    # "my_plr_mirrorGD_entropy-tuning.toml", # Пока не работает
    "my_plr_prodigy-tuning.toml",
    "my_plr_projGD_R_2-tuning.toml",
    "my_plr_rmsprop-tuning.toml",
    "my_plr_sgd-tuning.toml",
    "my_plr_signsgd-tuning.toml"
]

# %% [markdown]
# ## current dir should be tabular-dl-tabr

# %%
# %cd ..
# Out:
# /home/igoreshka/Desktop/ЛАБКА/TabularDL/tabular-dl-tabr

# %%
# %pwd
# Out:
# '/home/igoreshka/Desktop/ЛАБКА/TabularDL/tabular-dl-tabr'

# %%
for file in file_names:
    print(os.path.exists(f"./exp/mlp/adult/{file}"))
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
for file_name in file_names:
    command = f"python3 bin/go.py ./exp/mlp/adult/{file_name}"
    try:
        result = subprocess.run(command, shell=True, check=True, capture_output=True, text=False)
        print(f"Command executed successfully for {file_name}:\n{result.stdout}")
    except subprocess.CalledProcessError as e:
        print(f"Error executing command for {file_name}:\n{e.stderr}")
# Out:
# Command executed successfully for my_lr_lion-tuning.toml:
# ...

# %% [markdown]
# ## Если что то недоработало: Пробуем повторно ебануть, иначе удаляем директорию созданную и заново пускаем
